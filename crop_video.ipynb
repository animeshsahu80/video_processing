# %%
from conf import SAMPLE_INPUTS,SAMPLE_OUTPUTS
from moviepy.editor import *
from PIL import Image
from moviepy.video.fx.all import crop

# %%
source_path=os.path.join(SAMPLE_INPUTS,'sample.mp4')
CROPPED_VID_DIR=os.path.join(SAMPLE_OUTPUTS,'cropped')
os.makedirs(CROPPED_VID_DIR,exist_ok=True)
crop_vid_path=os.path.join(CROPPED_VID_DIR,'cropped.mp4')

# %%
clip=VideoFileClip(source_path)
subclip=clip.subclip(10,20) #cropping video from 10th to 20th sec

# %%
w,h=clip.size
cropped_clip=crop(subclip,width=500,height=500)   #adjust the parameters accordingly
cropped_clip.write_gif(crop_vid_path,fps=30,program='ffmpeg')
# Out:
#
#
#
#
#
#
# chunk:   0%|          | 1/221 [03:33<13:01:24, 213.11s/it, now=None]
# chunk:   0%|          | 1/221 [03:11<11:41:36, 191.35s/it, now=None]
#
#
# t:   1%|          | 2/300 [00:46<1:55:30, 23.26s/it, now=None]
#
#                                                                     A
#
#
#
#
#
# chunk:   0%|          | 1/221 [03:33<13:01:26, 213.12s/it, now=None]
# chunk:   0%|          | 1/221 [03:11<11:41:38, 191.36s/it, now=None]
#
#
# t:   1%|          | 2/300 [00:46<1:55:31, 23.26s/it, now=None]
#
# chunk:   0%|          | 1/221 [01:15<4:35:13, 75.06s/it, now=None]
#
#
#
# t:   0%|          | 0/300 [00:00<?, ?it/s, now=None]
#
#
#
# t:   2%|▏         | 7/300 [00:00<00:04, 68.56it/s, now=None]
# MoviePy - Building file  /home/animesh/video_processing/data/samples/outputs/cropped/cropped.mp4
# MoviePy - - Generating GIF frames.
# t:   4%|▍         | 13/300 [00:00<00:04, 62.60it/s, now=None]
#
#
#
# t:   6%|▋         | 19/300 [00:00<00:04, 60.30it/s, now=None]
#
#
#
# t:   8%|▊         | 25/300 [00:00<00:04, 59.01it/s, now=None]
#
#
#
# t:  11%|█         | 32/300 [00:00<00:04, 60.38it/s, now=None]
#
#
#
# t:  13%|█▎        | 39/300 [00:00<00:04, 60.71it/s, now=None]
#
#
#
# t:  15%|█▌        | 45/300 [00:00<00:04, 59.34it/s, now=None]
#
#
#
# t:  17%|█▋        | 51/300 [00:00<00:05, 48.40it/s, now=None]
#
#
#
# t:  19%|█▊        | 56/300 [00:01<00:05, 41.39it/s, now=None]
#
#
#
# t:  20%|██        | 61/300 [00:01<00:06, 39.13it/s, now=None]
#
#
#
# t:  22%|██▏       | 66/300 [00:01<00:05, 40.18it/s, now=None]
#
#
#
# t:  24%|██▎       | 71/300 [00:01<00:05, 39.74it/s, now=None]
#
#
#
# t:  25%|██▌       | 76/300 [00:01<00:05, 38.75it/s, now=None]
#
#
#
# t:  27%|██▋       | 80/300 [00:01<00:06, 35.65it/s, now=None]
#
#
#
# t:  28%|██▊       | 84/300 [00:01<00:05, 36.10it/s, now=None]
#
#
#
# t:  29%|██▉       | 88/300 [00:01<00:06, 35.03it/s, now=None]
#
#
#
# t:  31%|███       | 92/300 [00:02<00:06, 33.52it/s, now=None]
#
#
#
# t:  32%|███▏      | 97/300 [00:02<00:05, 37.05it/s, now=None]
#
#
#
# t:  34%|███▍      | 102/300 [00:02<00:05, 38.62it/s, now=None]
#
#
#
# t:  36%|███▌      | 107/300 [00:02<00:04, 39.95it/s, now=None]
#
#
#
# t:  37%|███▋      | 112/300 [00:02<00:04, 42.30it/s, now=None]
#
#
#
# t:  39%|███▉      | 117/300 [00:02<00:04, 42.57it/s, now=None]
#
#
#
# t:  41%|████      | 122/300 [00:02<00:04, 43.99it/s, now=None]
#
#
#
# t:  42%|████▏     | 127/300 [00:02<00:03, 45.40it/s, now=None]
#
#
#
# t:  44%|████▍     | 132/300 [00:02<00:03, 44.72it/s, now=None]
#
#
#
# t:  46%|████▌     | 137/300 [00:03<00:03, 45.19it/s, now=None]
#
#
#
# t:  47%|████▋     | 142/300 [00:03<00:03, 45.01it/s, now=None]
#
#
#
# t:  49%|████▉     | 147/300 [00:03<00:03, 45.21it/s, now=None]
#
#
#
# t:  51%|█████     | 152/300 [00:03<00:03, 43.73it/s, now=None]
#
#
#
# t:  52%|█████▏    | 157/300 [00:03<00:03, 40.24it/s, now=None]
#
#
#
# t:  54%|█████▍    | 162/300 [00:03<00:03, 39.05it/s, now=None]
#
#
#
# t:  55%|█████▌    | 166/300 [00:03<00:03, 38.06it/s, now=None]
#
#
#
# t:  57%|█████▋    | 170/300 [00:03<00:03, 35.18it/s, now=None]
#
#
#
# t:  58%|█████▊    | 174/300 [00:04<00:03, 34.12it/s, now=None]
#
#
#
# t:  59%|█████▉    | 178/300 [00:04<00:03, 33.38it/s, now=None]
#
#
#
# t:  61%|██████    | 182/300 [00:04<00:03, 34.37it/s, now=None]
#
#
#
# t:  62%|██████▏   | 186/300 [00:04<00:03, 32.75it/s, now=None]
#
#
#
# t:  63%|██████▎   | 190/300 [00:04<00:03, 31.41it/s, now=None]
#
#
#
# t:  65%|██████▍   | 194/300 [00:04<00:03, 32.84it/s, now=None]
#
#
#
# t:  66%|██████▌   | 198/300 [00:04<00:03, 32.99it/s, now=None]
#
#
#
# t:  67%|██████▋   | 202/300 [00:05<00:03, 28.10it/s, now=None]
#
#
#
# t:  68%|██████▊   | 205/300 [00:05<00:03, 28.42it/s, now=None]
#
#
#
# t:  69%|██████▉   | 208/300 [00:05<00:03, 28.82it/s, now=None]
#
#
#
# t:  71%|███████   | 212/300 [00:05<00:02, 30.16it/s, now=None]
#
#
#
# t:  72%|███████▏  | 216/300 [00:05<00:02, 28.19it/s, now=None]
#
#
#
# t:  73%|███████▎  | 219/300 [00:05<00:03, 23.51it/s, now=None]
#
#
#
# t:  74%|███████▍  | 222/300 [00:05<00:03, 24.20it/s, now=None]
#
#
#
# t:  75%|███████▌  | 225/300 [00:05<00:02, 25.41it/s, now=None]
#
#
#
# t:  76%|███████▌  | 228/300 [00:06<00:02, 26.07it/s, now=None]
#
#
#
# t:  77%|███████▋  | 232/300 [00:06<00:02, 28.33it/s, now=None]
#
#
#
# t:  79%|███████▊  | 236/300 [00:06<00:02, 28.63it/s, now=None]
#
#
#
# t:  80%|████████  | 240/300 [00:06<00:01, 30.17it/s, now=None]
#
#
#
# t:  81%|████████▏ | 244/300 [00:06<00:01, 31.20it/s, now=None]
#
#
#
# t:  83%|████████▎ | 248/300 [00:06<00:01, 32.06it/s, now=None]
#
#
#
# t:  84%|████████▍ | 252/300 [00:06<00:01, 31.45it/s, now=None]
#
#
#
# t:  85%|████████▌ | 256/300 [00:06<00:01, 31.85it/s, now=None]
#
#
#
# t:  87%|████████▋ | 260/300 [00:07<00:01, 31.75it/s, now=None]
#
#
#
# t:  88%|████████▊ | 264/300 [00:07<00:01, 32.94it/s, now=None]
#
#
#
# t:  89%|████████▉ | 268/300 [00:07<00:00, 34.43it/s, now=None]
#
#
#
# t:  91%|█████████ | 272/300 [00:07<00:00, 34.16it/s, now=None]
#
#
#
# t:  92%|█████████▏| 276/300 [00:07<00:00, 33.70it/s, now=None]
#
#
#
# t:  93%|█████████▎| 280/300 [00:07<00:00, 34.07it/s, now=None]
#
#
#
# t:  95%|█████████▍| 284/300 [00:07<00:00, 32.74it/s, now=None]
#
#
#
# t:  96%|█████████▌| 288/300 [00:07<00:00, 34.19it/s, now=None]
#
#
#
# t:  97%|█████████▋| 292/300 [00:07<00:00, 34.05it/s, now=None]
#
#
#
# t:  99%|█████████▊| 296/300 [00:08<00:00, 33.60it/s, now=None]
#
#
#
# t: 100%|██████████| 300/300 [00:08<00:00, 33.05it/s, now=None]
#
#
#
#
#
#
#
#
#
#
# chunk:   0%|          | 1/221 [03:20<12:13:51, 200.14s/it, now=None]
#
# chunk:   0%|          | 1/221 [03:41<13:33:39, 221.91s/it, now=None]A
#
#
# t:   1%|          | 2/300 [00:55<2:17:20, 27.65s/it, now=None]
# MoviePy - - File ready: /home/animesh/video_processing/data/samples/outputs/cropped/cropped.mp4.
